# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion = keras.datasets.fashion_mnist
(trainImages, trainLabels), (testImages, testLabels) = fashion.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
imgIndex = 0
img = trainImages[imgIndex]
print("Image Label :",trainLabels[imgIndex])
plt.imshow(img)
# Out:
# Image Label : 9

# %%
print(trainImages.shape)
print(testImages.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation=tf.nn.relu),
                          keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam',
           loss = 'sparse_categorical_crossentropy',
           metrics=['accuracy'])

# %%
model.fit(trainImages, trainLabels, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 3.0300 - accuracy: 0.6799
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6931 - accuracy: 0.7232
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6300 - accuracy: 0.7483
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5703 - accuracy: 0.7951
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5350 - accuracy: 0.8152

# %%
model.evaluate(testImages, testLabels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5527 - accuracy: 0.8174
# [0.5526623725891113, 0.8173999786376953]

# %%
predictions = model.predict(testImages[0:5])

# Print the predicted labels
print(predictions)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# [[4.22989382e-14 2.74049061e-10 2.70191533e-30 1.60821453e-10
#   9.72136644e-22 1.63511783e-02 7.32701582e-24 1.04320765e-01
#   3.76315995e-07 8.79327655e-01]
#  [1.85058278e-03 1.32453104e-03 7.81661630e-01 5.54080470e-04
#   1.76742733e-01 4.93143409e-18 3.78663540e-02 2.68561408e-20
#   9.22448464e-08 5.74749593e-31]
#  [4.78084411e-15 1.00000000e+00 0.00000000e+00 1.83560256e-14
#   4.32992088e-23 0.00000000e+00 8.29788421e-31 0.00000000e+00
#   6.77455318e-23 0.00000000e+00]
#  [8.35353210e-15 1.00000000e+00 1.17673915e-36 6.80790710e-12
#   3.35783992e-19 0.00000000e+00 1.20918520e-27 0.00000000e+00
#   1.07133862e-22 0.00000000e+00]
#  [1.28131434e-01 2.44295038e-02 1.46663859e-01 6.87345788e-02
#   5.35522439e-02 5.12214079e-02 4.18907434e-01 3.55004333e-02
#   5.58849573e-02 1.69740524e-02]]

# %%
print(np.argmax(predictions, axis=1))
# Print the actual label values
print(testLabels[0:5])
# Out:
# [9 2 1 1 6]
# [9 2 1 1 6]

# %%
for i in range(0,5):
  plt.imshow(testImages[i], cmap='gray')
  plt.show()
